# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import itertools
import os

# Define the genres to be used in the combinations (customizable)
selected_genres = ['Rap', 'Blues', 'Rock', 'Electronic', 'Reggae', 'Country', 'Metal', 'Pop', 'Jazz']

# Function to load the dataset for a given set of genres and perform evaluation
def evaluate_xgb_with_genres(genres, num_estimators, learning_rate):
    # Create the file name based on the genre combination
    file_names = [f'../GeneratedData/3secondsData/{genre}_dataset.csv' for genre in genres]
    
    # Load the corresponding datasets for the selected genres
    data_frames = []
    for file_name in file_names:
        if os.path.exists(file_name):
            data_frames.append(pd.read_csv(file_name))
        else:
            print(f"Warning: {file_name} not found.")
    
    if not data_frames:
        print(f"No datasets found for {genres}. Skipping combination.")
        return None

    # Concatenate all genre datasets into a single dataframe
    data = pd.concat(data_frames, ignore_index=True)
    
    # Separate features and target (label)
    y = data['label']
    X = data.drop(columns=['label', 'TrackID', 'Genre', 'filename'])

    # Normalize X
    from sklearn.preprocessing import MinMaxScaler
    min_max_scaler = MinMaxScaler()
    np_scaled = min_max_scaler.fit_transform(X)
    X = pd.DataFrame(np_scaled, columns=X.columns)

    # Split the data (20-30% testing split)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    # Encode the labels
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_test_encoded = le.transform(y_test)

    # Define the XGBoost model with the given hyperparameters
    xgb = XGBClassifier(n_estimators=num_estimators, learning_rate=learning_rate, random_state=42)

    # Train the model
    xgb.fit(X_train, y_train_encoded)

    # Predict and evaluate accuracy
    preds = xgb.predict(X_test)
    accuracy = accuracy_score(y_test_encoded, preds)

    # Return the results
    return accuracy, genres, num_estimators, learning_rate

# Generate all combinations of the selected genres with at least 8 genres in each combination
genre_combinations = [list(combo) for i in range(8, len(selected_genres) + 1) for combo in itertools.combinations(selected_genres, i)]

# Combinations of parameters to test
num_estimators_list = [500, 1000, 1500, 5000]
learning_rate_list = [ 0.1, 0.05, 0.01]

# List to store results
results = []

# Loop through each combination of genres, number of estimators, and learning rate
for genres in genre_combinations:
    for num_estimators in num_estimators_list:
        for learning_rate in learning_rate_list:
            result = evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
            if result:
                accuracy, genres_used, n_estimators, lr = result
                results.append({
                    'Genres': ', '.join(genres_used),
                    'Number of Estimators': n_estimators,
                    'Learning Rate': lr,
                    'Accuracy': accuracy
                })
                print(f"Genres: {', '.join(genres_used)} | "
                      f"Number of Estimators: {n_estimators} | "
                      f"Learning Rate: {lr} | "
                      f"Accuracy: {accuracy}")

# Save the results to a DataFrame
results_df = pd.DataFrame(results)

# Generate a short form of genre names (first two letters) to append to the file name
genre_abbr = ''.join([g[:2] for g in selected_genres])

# Write results to a CSV file with genre abbreviations in the file name
output_file = f'../GeneratedData/Model_Results_XGB_{genre_abbr}_Combinations.csv'
results_df.to_csv(output_file, index=False)

print(f'Model evaluation complete. Results saved to {output_file}')
# Out:
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.01 | Accuracy: 0.6328671328671329
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.05 | Accuracy: 0.7437562437562437
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.7537462537462537
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.025 | Accuracy: 0.7047952047952047
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.01 | Accuracy: 0.6818181818181818
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.05 | Accuracy: 0.7577422577422578
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.1 | Accuracy: 0.7657342657342657
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.025 | Accuracy: 0.7407592407592407
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.01 | Accuracy: 0.7102897102897103
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.05 | Accuracy: 0.7577422577422578
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.1 | Accuracy: 0.7632367632367633
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.025 | Accuracy: 0.7552447552447552
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.01 | Accuracy: 0.7537462537462537
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.05 | Accuracy: 0.7642357642357642
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.1 | Accuracy: 0.7607392607392608
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.025 | Accuracy: 0.7587412587412588
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 500 | Learning Rate: 0.01 | Accuracy: 0.6298701298701299
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 500 | Learning Rate: 0.05 | Accuracy: 0.7542457542457542
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.7752247752247752
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 500 | Learning Rate: 0.025 | Accuracy: 0.7082917082917083
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1000 | Learning Rate: 0.01 | Accuracy: 0.6923076923076923
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1000 | Learning Rate: 0.05 | Accuracy: 0.7772227772227772
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1000 | Learning Rate: 0.1 | Accuracy: 0.7747252747252747
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1000 | Learning Rate: 0.025 | Accuracy: 0.7522477522477522
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1500 | Learning Rate: 0.01 | Accuracy: 0.7197802197802198
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1500 | Learning Rate: 0.05 | Accuracy: 0.7792207792207793
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1500 | Learning Rate: 0.1 | Accuracy: 0.7727272727272727
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 1500 | Learning Rate: 0.025 | Accuracy: 0.7672327672327672
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 5000 | Learning Rate: 0.01 | Accuracy: 0.7702297702297702
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 5000 | Learning Rate: 0.05 | Accuracy: 0.7737262737262737
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 5000 | Learning Rate: 0.1 | Accuracy: 0.7732267732267732
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Metal, Jazz | Number of Estimators: 5000 | Learning Rate: 0.025 | Accuracy: 0.7797202797202797
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Pop, Jazz | Number of Estimators: 500 | Learning Rate: 0.01 | Accuracy: 0.6018981018981019
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Pop, Jazz | Number of Estimators: 500 | Learning Rate: 0.05 | Accuracy: 0.7202797202797203
# Genres: Rap, Blues, Rock, Electronic, Reggae, Country, Pop, Jazz | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.7452547452547452
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 78
#      76 for num_estimators in num_estimators_list:
#      77     for learning_rate in learning_rate_list:
# ---> 78         result = evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
#      79         if result:
#      80             accuracy, genres_used, n_estimators, lr = result
#
# Cell In[2], line 55, in evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
#      52 xgb = XGBClassifier(n_estimators=num_estimators, learning_rate=learning_rate, random_state=42)
#      54 # Train the model
# ---> 55 xgb.fit(X_train, y_train_encoded)
#      57 # Predict and evaluate accuracy
#      58 preds = xgb.predict(X_test)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import os

# Define the fixed set of genres to use
selected_genres = ['Blues', 'Country', 'Jazz', 'Metal', 'Pop', 'Reggae', 'Rock']

# Function to load the dataset for a given set of genres and perform evaluation
def evaluate_xgb_with_genres(genres, num_estimators, learning_rate):
    # Create the file name based on the genre combination
    file_names = [f'../GeneratedData/3secondsData/{genre}_dataset.csv' for genre in genres]
    
    # Load the corresponding datasets for the selected genres
    data_frames = []
    for file_name in file_names:
        if os.path.exists(file_name):
            data_frames.append(pd.read_csv(file_name))
        else:
            print(f"Warning: {file_name} not found.")
    
    if not data_frames:
        print(f"No datasets found for {genres}. Skipping combination.")
        return None

    # Concatenate all genre datasets into a single dataframe
    data = pd.concat(data_frames, ignore_index=True)
    
    # Separate features and target (label)
    y = data['label']
    X = data.drop(columns=['label', 'TrackID', 'Genre', 'filename'])

    # Normalize X
    from sklearn.preprocessing import MinMaxScaler
    min_max_scaler = MinMaxScaler()
    np_scaled = min_max_scaler.fit_transform(X)
    X = pd.DataFrame(np_scaled, columns=X.columns)

    # Split the data (20-30% testing split)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    # Encode the labels
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_test_encoded = le.transform(y_test)

    # Define the XGBoost model with the given hyperparameters
    xgb = XGBClassifier(n_estimators=num_estimators, learning_rate=learning_rate, random_state=42)

    # Train the model
    xgb.fit(X_train, y_train_encoded)

    # Predict and evaluate accuracy
    preds = xgb.predict(X_test)
    accuracy = accuracy_score(y_test_encoded, preds)

    # Return the results
    return accuracy, genres, num_estimators, learning_rate

# Define hyperparameters to test
num_estimators_list = [500, 1000, 1500, 5000]
learning_rate_list = [0.1, 0.05, 0.01]

# List to store results
results = []

# Loop through the parameters for the single set of genres
for num_estimators in num_estimators_list:
    for learning_rate in learning_rate_list:
        result = evaluate_xgb_with_genres(selected_genres, num_estimators, learning_rate)
        if result:
            accuracy, genres_used, n_estimators, lr = result
            results.append({
                'Genres': ', '.join(genres_used),
                'Number of Estimators': n_estimators,
                'Learning Rate': lr,
                'Accuracy': accuracy
            })
            print(f"Genres: {', '.join(genres_used)} | "
                  f"Number of Estimators: {n_estimators} | "
                  f"Learning Rate: {lr} | "
                  f"Accuracy: {accuracy}")

# Save the results to a DataFrame
results_df = pd.DataFrame(results)

# Generate a short form of genre names (first two letters) to append to the file name
genre_abbr = ''.join([g[:2] for g in selected_genres])

# Write results to a CSV file with genre abbreviations in the file name
output_file = f'../GeneratedData/Model_Results_XGB_{genre_abbr}_25p.csv'
results_df.to_csv(output_file, index=False)

print(f'Model evaluation complete. Results saved to {output_file}')
# Out:
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.723465016658734
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 500 | Learning Rate: 0.05 | Accuracy: 0.6987148976677773
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 500 | Learning Rate: 0.01 | Accuracy: 0.5992384578772013
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1000 | Learning Rate: 0.1 | Accuracy: 0.7277486910994765
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1000 | Learning Rate: 0.05 | Accuracy: 0.7253688719657306
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1000 | Learning Rate: 0.01 | Accuracy: 0.6530223702998572
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1500 | Learning Rate: 0.1 | Accuracy: 0.7277486910994765
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1500 | Learning Rate: 0.05 | Accuracy: 0.737743931461209
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 1500 | Learning Rate: 0.01 | Accuracy: 0.672536887196573
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 5000 | Learning Rate: 0.1 | Accuracy: 0.723465016658734
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 5000 | Learning Rate: 0.05 | Accuracy: 0.732032365540219
# Genres: Blues, Country, Jazz, Metal, Pop, Reggae, Rock | Number of Estimators: 5000 | Learning Rate: 0.01 | Accuracy: 0.7172774869109948
# Model evaluation complete. Results saved to ../GeneratedData/Model_Results_XGB_BlCoJaMePoReRo_30p.csv
