# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
import itertools
import os

# List of all possible genres
all_genres = ['Blues', 'Country', 'Electronic', 'Folk', 'Jazz', 'Latin', 'Metal', 'Pop', 'Punk', 'Rap', 'Reggae', 'RnB', 'Rock', 'World', 'New Age']

# Function to load the dataset for a given set of genres and perform evaluation
def evaluate_xgb_with_genres(genres, num_estimators, learning_rate):
    # Create the file name based on the genre combination
    file_names = [f'../GeneratedData/3secondsData/{genre}_dataset.csv' for genre in genres]
    
    # Load the corresponding datasets for the selected genres
    data_frames = []
    for file_name in file_names:
        if os.path.exists(file_name):
            data_frames.append(pd.read_csv(file_name))
        else:
            print(f"Warning: {file_name} not found.")
    
    if not data_frames:
        print(f"No datasets found for {genres}. Skipping combination.")
        return None

    # Concatenate all genre datasets into a single dataframe
    data = pd.concat(data_frames, ignore_index=True)
    
    # Separate features and target (label)
    y = data['label']
    X = data.drop(columns=['label', 'TrackID', 'Genre', 'filename'])

    # Normalize X
    from sklearn.preprocessing import MinMaxScaler
    min_max_scaler = MinMaxScaler()
    np_scaled = min_max_scaler.fit_transform(X)
    X = pd.DataFrame(np_scaled, columns=X.columns)

    # Split the data (20-30% testing split)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

    # Encode the labels
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    y_train_encoded = le.fit_transform(y_train)
    y_test_encoded = le.transform(y_test)

    # Define the XGBoost model with the given hyperparameters
    xgb = XGBClassifier(n_estimators=num_estimators, learning_rate=learning_rate, random_state=42)

    # Train the model
    xgb.fit(X_train, y_train_encoded)

    # Predict and evaluate accuracy
    preds = xgb.predict(X_test)
    accuracy = accuracy_score(y_test_encoded, preds)

    # Return the results
    return accuracy, genres, num_estimators, learning_rate

# Generate all combinations of genres with at least 8 genres in each combination
genre_combinations = [list(combo) for i in range(8, len(all_genres) + 1) for combo in itertools.combinations(all_genres, i)]

# Combinations of parameters to test
num_estimators_list = [500, 1000, 1500,5000,10000]
learning_rate_list = [0.01, 0.05, 0.1,0.025,0.001]

# List to store results
results = []

# Loop through each combination of genres, number of estimators, and learning rate
for genres in genre_combinations:
    for num_estimators in num_estimators_list:
        for learning_rate in learning_rate_list:
            result = evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
            if result:
                accuracy, genres_used, n_estimators, lr = result
                results.append({
                    'Genres': ', '.join(genres_used),
                    'Number of Estimators': n_estimators,
                    'Learning Rate': lr,
                    'Accuracy': accuracy
                })
                print(f"Genres: {', '.join(genres_used)} | "
                      f"Number of Estimators: {n_estimators} | "
                      f"Learning Rate: {lr} | "
                      f"Accuracy: {accuracy}")

# Save the results to a DataFrame and write to CSV
results_df = pd.DataFrame(results)
results_df.to_csv('../GeneratedData/Model_Results_XGB_All_Combinations.csv', index=False)

print('Model evaluation complete. Results saved to Model_Results_XGB_All_Combinations.csv')
# Out:
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.01 | Accuracy: 0.6340489266100848
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.05 | Accuracy: 0.7319021467798302
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.7503744383424863
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.025 | Accuracy: 0.6939590614078882
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 500 | Learning Rate: 0.001 | Accuracy: 0.49675486769845234
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.01 | Accuracy: 0.6794807788317524
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.05 | Accuracy: 0.7488766849725412
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.1 | Accuracy: 0.7488766849725412
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.025 | Accuracy: 0.72690963554668
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1000 | Learning Rate: 0.001 | Accuracy: 0.528207688467299
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.01 | Accuracy: 0.7109335996005991
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.05 | Accuracy: 0.7508736894658014
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.1 | Accuracy: 0.7478781827259111
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.025 | Accuracy: 0.7403894158761857
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 1500 | Learning Rate: 0.001 | Accuracy: 0.5591612581128308
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.01 | Accuracy: 0.7413879181228158
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.05 | Accuracy: 0.7503744383424863
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.1 | Accuracy: 0.7383924113829257
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.025 | Accuracy: 0.746380429355966
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 5000 | Learning Rate: 0.001 | Accuracy: 0.6340489266100848
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 10000 | Learning Rate: 0.01 | Accuracy: 0.7488766849725412
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 10000 | Learning Rate: 0.05 | Accuracy: 0.7433849226160759
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 10000 | Learning Rate: 0.1 | Accuracy: 0.7373939091362955
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal, Pop | Number of Estimators: 10000 | Learning Rate: 0.025 | Accuracy: 0.744882675986021
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, Metal,
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 500 | Learning Rate: 0.1 | Accuracy: 0.7348976535197205
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 500 | Learning Rate: 0.025 | Accuracy: 0.6774837743384923
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 500 | Learning Rate: 0.001 | Accuracy: 0.46679980029955065
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1000 | Learning Rate: 0.01 | Accuracy: 0.6645032451323015
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1000 | Learning Rate: 0.05 | Accuracy: 0.7413879181228158
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1000 | Learning Rate: 0.1 | Accuracy: 0.7378931602596106
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1000 | Learning Rate: 0.025 | Accuracy: 0.7129306040938592
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1000 | Learning Rate: 0.001 | Accuracy: 0.49326010983524715
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1500 | Learning Rate: 0.01 | Accuracy: 0.6934598102845732
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1500 | Learning Rate: 0.05 | Accuracy: 0.7398901647528707
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1500 | Learning Rate: 0.1 | Accuracy: 0.7348976535197205
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1500 | Learning Rate: 0.025 | Accuracy: 0.7294058911632552
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 1500 | Learning Rate: 0.001 | Accuracy: 0.528207688467299
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 5000 | Learning Rate: 0.01 | Accuracy: 0.7329006490264603
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 5000 | Learning Rate: 0.05 | Accuracy: 0.7398901647528707
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 5000 | Learning Rate: 0.1 | Accuracy: 0.7329006490264603
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 5000 | Learning Rate: 0.025 | Accuracy: 0.7398901647528707
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 5000 | Learning Rate: 0.001 | Accuracy: 0.6115826260609086
# Genres: Blues, Country, Electronic, Folk, Jazz, Latin, World, New Age | Number of Estimators: 10000 | Learning Rate: 0.01 | Accuracy: 0.7398901647528707
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 78
#      76 for num_estimators in num_estimators_list:
#      77     for learning_rate in learning_rate_list:
# ---> 78         result = evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
#      79         if result:
#      80             accuracy, genres_used, n_estimators, lr = result
#
# Cell In[4], line 55, in evaluate_xgb_with_genres(genres, num_estimators, learning_rate)
#      52 xgb = XGBClassifier(n_estimators=num_estimators, learning_rate=learning_rate, random_state=42)
#      54 # Train the model
# ---> 55 xgb.fit(X_train, y_train_encoded)
#      57 # Predict and evaluate accuracy
#      58 preds = xgb.predict(X_test)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/sklearn.py:1531, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1511 model, metric, params = self._configure_fit(xgb_model, params)
#    1512 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1513     missing=self.missing,
#    1514     X=X,
#    (...)
#    1528     feature_types=self.feature_types,
#    1529 )
# -> 1531 self._Booster = train(
#    1532     params,
#    1533     train_dmatrix,
#    1534     self.get_num_boosting_rounds(),
#    1535     evals=evals,
#    1536     early_stopping_rounds=self.early_stopping_rounds,
#    1537     evals_result=evals_result,
#    1538     obj=obj,
#    1539     custom_metric=metric,
#    1540     verbose_eval=verbose,
#    1541     xgb_model=model,
#    1542     callbacks=self.callbacks,
#    1543 )
#    1545 if not callable(self.objective):
#    1546     self.objective = params["objective"]
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File /opt/anaconda3/envs/SongClassifier/lib/python3.12/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
